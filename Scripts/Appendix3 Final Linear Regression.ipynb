# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Sklearn
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from scipy.stats import boxcox, skew

import warnings
warnings.filterwarnings("ignore")

# Weights & Biases (optional)
import wandb
from itertools import product

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 1: Load and Split Data -------------------------
# ----------------------------------------------------------------------------
# Load dataset
train_df = pd.read_csv("Dataset1_train.csv")
test_df = pd.read_csv("Dataset1_test.csv")

# Define numerical features and target variable
numeric_features = [
    "Engine Size(L)", "Cylinders", "Gearbox_Number",
    "Fuel Consumption City (L/100 km)", "Fuel Consumption Hwy (L/100 km)",
    "Fuel Consumption Comb (L/100 km)", "Fuel Consumption Comb (mpg)"
]
categorical_features = ["Make"]  # Only encoding `Make`
target = "CO2 Emissions(g/km)"


# ----------------------------------------------------------------------------
# -------------------- 📌 Step 2: K-Fold Target Encoding ----------------------
# ----------------------------------------------------------------------------
kf = KFold(n_splits=5, shuffle=True, random_state=42)

train_encoded_df = train_df.copy()
for cat in categorical_features:
    train_encoded_df[f"{cat}_encoded"] = np.nan
    for train_idx, val_idx in kf.split(train_df):
        fold_train = train_df.iloc[train_idx]
        target_mean = fold_train.groupby(cat)[target].mean()
        valid_idx = train_encoded_df.index.intersection(val_idx)
        train_encoded_df.loc[valid_idx, f"{cat}_encoded"] = (
            train_df.loc[valid_idx, cat].map(target_mean)
        )
    # Fill any missing with overall mean of the target
    train_encoded_df[f"{cat}_encoded"].fillna(train_df[target].mean(), inplace=True)

test_encoded_df = test_df.copy()
for cat in categorical_features:
    overall_mapping = train_df.groupby(cat)[target].mean()
    test_encoded_df[f"{cat}_encoded"] = test_df[cat].map(overall_mapping)
    test_encoded_df[f"{cat}_encoded"].fillna(train_df[target].mean(), inplace=True)

# Drop original categorical columns
train_encoded_df.drop(columns=categorical_features, inplace=True)
test_encoded_df.drop(columns=categorical_features, inplace=True)

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 3: (Optional) Box-Cox Transformation -----------
# ----------------------------------------------------------------------------
skewness_value = skew(train_df[target])
apply_boxcox = False if -1 <= skewness_value <= 1 else True

print(f"\nSkewness of '{target}': {skewness_value:.2f}")
if apply_boxcox:
    print("Applying Box-Cox transformation...")
    train_encoded_df[target], lambda_value = boxcox(train_encoded_df[target] + 1)
    test_encoded_df[target] = boxcox(test_encoded_df[target] + 1, lmbda=lambda_value)

    # Plot before and after
    fig, ax = plt.subplots(1, 2, figsize=(12, 5))
    sns.histplot(train_df[target], bins=30, kde=True, ax=ax[0])
    ax[0].set_title("Original Target Distribution")
    sns.histplot(train_encoded_df[target], bins=30, kde=True, ax=ax[1])
    ax[1].set_title(f"Box-Cox Target (λ = {lambda_value:.2f})")
    plt.tight_layout()
    plt.show()
else:
    print("Skipping Box-Cox (skewness within [-1,1]).")

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 4: Correlation-based Feature Removal -----------
# ----------------------------------------------------------------------------
correlation_matrix = train_encoded_df.corr()

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Pearson Correlation Heatmap")
plt.show()

# 1) Remove features that are highly correlated with each other (> 0.9)
corr_threshold_remove = 0.9

# Sort by absolute correlation with target
sorted_features = correlation_matrix[target].abs().sort_values(ascending=False).index.tolist()
sorted_features.remove(target)

selected_features = []
for col in sorted_features:
    drop_flag = False
    for kept in selected_features:
        if abs(correlation_matrix.loc[col, kept]) > corr_threshold_remove:
            drop_flag = True
            break
    if not drop_flag:
        selected_features.append(col)

print("\nFeatures remaining after removing collinearity (corr>0.9):")
print(selected_features)

# 2) Keep only features that have correlation > 0.7 with the target
corr_threshold_keep = 0.7
high_corr_features = [
    f for f in selected_features
    if abs(correlation_matrix[target][f]) > corr_threshold_keep
]

print("\nSelected Features for Model (corr>0.7 w/ target):")
print(high_corr_features)

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 5: Final Feature/Target Split ------------------
# ----------------------------------------------------------------------------
X_train_raw = train_encoded_df[high_corr_features]
y_train_raw = train_encoded_df[target]
X_test_raw  = test_encoded_df[high_corr_features]
y_test_raw  = test_encoded_df[target]

print("\nShapes before Scaling:")
print("X_train:", X_train_raw.shape, "y_train:", y_train_raw.shape)
print("X_test: ", X_test_raw.shape,  "y_test: ", y_test_raw.shape)

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 6: Standardize Data (Optional) -----------------
# ----------------------------------------------------------------------------
apply_standardization = True

if apply_standardization:
    scaler_X = StandardScaler()
    X_train_scaled = scaler_X.fit_transform(X_train_raw)
    X_test_scaled  = scaler_X.transform(X_test_raw)
    
    # Optional: scale the target as well
    scaler_y = StandardScaler()
    y_train_scaled = scaler_y.fit_transform(y_train_raw.values.reshape(-1, 1))
    y_test_scaled  = scaler_y.transform(y_test_raw.values.reshape(-1, 1))
    
    X_train_final = X_train_scaled
    X_test_final  = X_test_scaled
    y_train_final = y_train_scaled.ravel()  # flatten for ElasticNet
    y_test_final  = y_test_scaled.ravel()
    
    # For reference:
    X_train_scaled_df = pd.DataFrame(X_train_scaled, index=X_train_raw.index, columns=X_train_raw.columns)
    print("\nAfter Standardization (X_train) Mean:\n", X_train_scaled_df.mean())
    print("\nAfter Standardization (X_train) Std:\n",  X_train_scaled_df.std())
    
    print("\nStandardization applied.")
else:
    X_train_final = X_train_raw.values
    X_test_final  = X_test_raw.values
    y_train_final = y_train_raw.values
    y_test_final  = y_test_raw.values
    
    print("\nNo Standardization applied.")

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 7: Hyperparameter Tuning (ElasticNet) ----------
# ----------------------------------------------------------------------------
# Example hyperparameter ranges for ElasticNet
# (Adjust or expand as needed)
alpha_options = [0.1, 1.0, 10.0]
l1_ratios = [0.2, 0.5, 0.8]

k_folds = 20
random_state = 42

best_val_loss = float('inf')
best_hyperparams = None
results = []

# Start KFold
outer_kf = KFold(n_splits=k_folds, shuffle=True, random_state=random_state)

for (alpha_val, l1_val) in product(alpha_options, l1_ratios):
    # Start a wandb run (remove if not using wandb)
    run_id = wandb.util.generate_id()
    wandb.init(
        project="elasticnet-kfold-hyperparameter-sweep",
        id=run_id,
        config={
            "alpha": alpha_val,
            "l1_ratio": l1_val,
            "k_folds": k_folds
        },
        reinit=True
    )
    
    print(f"\n=== Hyperparams: alpha={alpha_val}, l1_ratio={l1_val} ===")
    
    fold_losses = []
    for fold_idx, (train_idx, val_idx) in enumerate(outer_kf.split(X_train_final)):
        X_train_fold = X_train_final[train_idx]
        y_train_fold = y_train_final[train_idx]
        
        X_val_fold = X_train_final[val_idx]
        y_val_fold = y_train_final[val_idx]
        
        # Create and fit the ElasticNet model
        model = ElasticNet(alpha=alpha_val, l1_ratio=l1_val, random_state=random_state)
        model.fit(X_train_fold, y_train_fold)
        
        # Predict on validation fold
        val_preds = model.predict(X_val_fold)
        fold_mse = mean_squared_error(y_val_fold, val_preds)
        
        fold_losses.append(fold_mse)
        
        # Log fold metrics
        wandb.log({
            "fold": fold_idx+1,
            "val_mse": fold_mse
        })
        
        print(f"  Fold {fold_idx+1}: val MSE = {fold_mse:.4f}")
    
    # Average MSE across folds
    avg_mse = np.mean(fold_losses)
    wandb.log({"overall_val_mse": avg_mse})
    print(f"\nAvg Val MSE for alpha={alpha_val}, l1_ratio={l1_val}: {avg_mse:.4f}\n")
    
    # Keep track of best
    if avg_mse < best_val_loss:
        best_val_loss = avg_mse
        best_hyperparams = wandb.config
    
    results.append(((alpha_val, l1_val), avg_mse))
    wandb.finish()

print("\nBest hyperparams found:", best_hyperparams)
print("Best val MSE:", best_val_loss)

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 8: Train Final Model on Full Train ------------
# ----------------------------------------------------------------------------
wandb.init(project="elasticnet-kfold-hyperparameter-sweep", name="final_evaluation",
           config=best_hyperparams, reinit=True)

final_alpha   = best_hyperparams["alpha"]
final_l1_ratio= best_hyperparams["l1_ratio"]

final_model = ElasticNet(alpha=final_alpha, l1_ratio=final_l1_ratio, random_state=random_state)
final_model.fit(X_train_final, y_train_final)

# ----------------------------------------------------------------------------
# -------------------- 📌 Step 9: Evaluate on Test Set ------------------------
# ----------------------------------------------------------------------------
test_preds = final_model.predict(X_test_final)
mse_val = mean_squared_error(y_test_final, test_preds)
r2_val  = r2_score(y_test_final, test_preds)
mae_val = mean_absolute_error(y_test_final, test_preds)
mape_val= mean_absolute_percentage_error(y_test_final, test_preds)

print(f"\nFinal Test MSE: {mse_val:.4f}")
print(f"Final R² Score: {r2_val:.4f}")
print(f"Final MAE: {mae_val:.4f}")
print(f"Final MAPE: {mape_val:.4f}")

wandb.log({"Final Test MSE": mse_val, "Final Test R2": r2_val})

# Plot predicted vs actual
plt.figure(figsize=(6, 6))
plt.scatter(y_test_final, test_preds, alpha=0.6)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("ElasticNet: Final Predictions vs. Actual")
mn, mx = min(y_test_final), max(y_test_final)
plt.plot([mn, mx], [mn, mx], color="red", linestyle="--")
plt.show()

wandb.finish()
print("Done.")
# Out:
# Skewness of 'CO2 Emissions(g/km)': 0.51
# Skipping Box-Cox (skewness within [-1,1]).
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Features remaining after removing collinearity (corr>0.9):
# ['Fuel Consumption City (L/100 km)', 'Engine Size(L)', 'Make_encoded', 'Vehicle Class_SUV - STANDARD', 'Fuel Type_X', 'Vehicle Class_PICKUP TRUCK - STANDARD', 'Fuel Type_Z', 'Vehicle Class_VAN - PASSENGER', 'Vehicle Class_MID-SIZE', 'Model Features_Four-wheel drive', 'Vehicle Class_STATION WAGON - SMALL', 'Gearbox_Number', 'Gearbox_Type', 'Vehicle Class_SUV - SMALL', 'Vehicle Class_TWO-SEATER', 'Model Features_Flexible-fuel vehicle', 'Fuel Type_E', 'Vehicle Class_VAN - CARGO', 'Vehicle Class_PICKUP TRUCK - SMALL', 'Vehicle Class_FULL-SIZE', 'Vehicle Class_MINICOMPACT', 'Model Features_Long wheelbase', 'Vehicle Class_SPECIAL PURPOSE VEHICLE', 'Vehicle Class_MINIVAN', 'Model Features_Short wheelbase', 'Vehicle Class_SUBCOMPACT', 'Vehicle Class_STATION WAGON - MID-SIZE']
#
# Selected Features for Model (corr>0.7 w/ target):
# ['Fuel Consumption City (L/100 km)', 'Engine Size(L)']
#
# Shapes before Scaling:
# X_train: (5907, 2) y_train: (5907,)
# X_test:  (1477, 2) y_test:  (1477,)
#
# After Standardization (X_train) Mean:
#  Fuel Consumption City (L/100 km)   -8.660755e-17
# Engine Size(L)                      9.683205e-17
# dtype: float64
#
# After Standardization (X_train) Std:
#  Fuel Consumption City (L/100 km)    1.000085
# Engine Size(L)                      1.000085
# dtype: float64
#
# Standardization applied.
# wandb: Currently logged in as: yhanluo22 (yhanluo22-imperial-college-london) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033002-g46k5ff6</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/g46k5ff6' target="_blank">fiery-dew-91</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/g46k5ff6' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/g46k5ff6</a>
# === Hyperparams: alpha=0.1, l1_ratio=0.2 ===
#   Fold 1: val MSE = 0.1255
#   Fold 2: val MSE = 0.1434
#   Fold 3: val MSE = 0.1648
#   Fold 4: val MSE = 0.1347
#   Fold 5: val MSE = 0.1159
#   Fold 6: val MSE = 0.1685
#   Fold 7: val MSE = 0.1198
#   Fold 8: val MSE = 0.1463
#   Fold 9: val MSE = 0.1419
#   Fold 10: val MSE = 0.1595
#   Fold 11: val MSE = 0.1433
#   Fold 12: val MSE = 0.1247
#   Fold 13: val MSE = 0.1098
#   Fold 14: val MSE = 0.1422
#   Fold 15: val MSE = 0.1586
#   Fold 16: val MSE = 0.0896
#   Fold 17: val MSE = 0.1435
#   Fold 18: val MSE = 0.1211
#   Fold 19: val MSE = 0.1135
#   Fold 20: val MSE = 0.1384
#
# Avg Val MSE for alpha=0.1, l1_ratio=0.2: 0.1353
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃█▄▆▆▇▆▄▃▆▇▁▆▄▃▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>0.13525</td></tr><tr><td>val_mse</td><td>0.13841</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fiery-dew-91</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/g46k5ff6' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/g46k5ff6</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033002-g46k5ff6\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033005-slzke8r2</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/slzke8r2' target="_blank">legendary-field-92</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/slzke8r2' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/slzke8r2</a>
# === Hyperparams: alpha=0.1, l1_ratio=0.5 ===
#   Fold 1: val MSE = 0.1271
#   Fold 2: val MSE = 0.1455
#   Fold 3: val MSE = 0.1675
#   Fold 4: val MSE = 0.1364
#   Fold 5: val MSE = 0.1173
#   Fold 6: val MSE = 0.1694
#   Fold 7: val MSE = 0.1213
#   Fold 8: val MSE = 0.1466
#   Fold 9: val MSE = 0.1441
#   Fold 10: val MSE = 0.1613
#   Fold 11: val MSE = 0.1446
#   Fold 12: val MSE = 0.1273
#   Fold 13: val MSE = 0.1113
#   Fold 14: val MSE = 0.1422
#   Fold 15: val MSE = 0.1600
#   Fold 16: val MSE = 0.0914
#   Fold 17: val MSE = 0.1451
#   Fold 18: val MSE = 0.1224
#   Fold 19: val MSE = 0.1147
#   Fold 20: val MSE = 0.1408
#
# Avg Val MSE for alpha=0.1, l1_ratio=0.5: 0.1368
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃█▄▆▆▇▆▄▃▆▇▁▆▄▃▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>0.13681</td></tr><tr><td>val_mse</td><td>0.14076</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">legendary-field-92</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/slzke8r2' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/slzke8r2</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033005-slzke8r2\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033008-0l8wyrn1</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/0l8wyrn1' target="_blank">dainty-dust-93</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/0l8wyrn1' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/0l8wyrn1</a>
# === Hyperparams: alpha=0.1, l1_ratio=0.8 ===
#   Fold 1: val MSE = 0.1293
#   Fold 2: val MSE = 0.1487
#   Fold 3: val MSE = 0.1710
#   Fold 4: val MSE = 0.1386
#   Fold 5: val MSE = 0.1194
#   Fold 6: val MSE = 0.1709
#   Fold 7: val MSE = 0.1233
#   Fold 8: val MSE = 0.1481
#   Fold 9: val MSE = 0.1475
#   Fold 10: val MSE = 0.1637
#   Fold 11: val MSE = 0.1467
#   Fold 12: val MSE = 0.1306
#   Fold 13: val MSE = 0.1135
#   Fold 14: val MSE = 0.1433
#   Fold 15: val MSE = 0.1625
#   Fold 16: val MSE = 0.0938
#   Fold 17: val MSE = 0.1474
#   Fold 18: val MSE = 0.1241
#   Fold 19: val MSE = 0.1167
#   Fold 20: val MSE = 0.1443
#
# Avg Val MSE for alpha=0.1, l1_ratio=0.8: 0.1392
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃█▄▆▆▇▆▄▃▅▇▁▆▄▃▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>0.13917</td></tr><tr><td>val_mse</td><td>0.14434</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dainty-dust-93</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/0l8wyrn1' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/0l8wyrn1</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033008-0l8wyrn1\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033011-pidrjh9z</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/pidrjh9z' target="_blank">dandy-glade-94</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/pidrjh9z' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/pidrjh9z</a>
# === Hyperparams: alpha=1.0, l1_ratio=0.2 ===
#   Fold 1: val MSE = 0.3247
#   Fold 2: val MSE = 0.3537
#   Fold 3: val MSE = 0.4013
#   Fold 4: val MSE = 0.3443
#   Fold 5: val MSE = 0.2912
#   Fold 6: val MSE = 0.3611
#   Fold 7: val MSE = 0.3350
#   Fold 8: val MSE = 0.2680
#   Fold 9: val MSE = 0.3126
#   Fold 10: val MSE = 0.3554
#   Fold 11: val MSE = 0.3225
#   Fold 12: val MSE = 0.3300
#   Fold 13: val MSE = 0.2997
#   Fold 14: val MSE = 0.2540
#   Fold 15: val MSE = 0.3296
#   Fold 16: val MSE = 0.2943
#   Fold 17: val MSE = 0.3189
#   Fold 18: val MSE = 0.3330
#   Fold 19: val MSE = 0.2754
#   Fold 20: val MSE = 0.3322
#
# Avg Val MSE for alpha=1.0, l1_ratio=0.2: 0.3218
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃▆▅▂▄▆▄▅▃▁▅▃▄▅▂▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>0.32184</td></tr><tr><td>val_mse</td><td>0.33217</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dandy-glade-94</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/pidrjh9z' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/pidrjh9z</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033011-pidrjh9z\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033014-86wqslqy</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/86wqslqy' target="_blank">happy-microwave-95</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/86wqslqy' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/86wqslqy</a>
# === Hyperparams: alpha=1.0, l1_ratio=0.5 ===
#   Fold 1: val MSE = 0.5097
#   Fold 2: val MSE = 0.5651
#   Fold 3: val MSE = 0.6295
#   Fold 4: val MSE = 0.5357
#   Fold 5: val MSE = 0.4680
#   Fold 6: val MSE = 0.5528
#   Fold 7: val MSE = 0.5270
#   Fold 8: val MSE = 0.4279
#   Fold 9: val MSE = 0.5039
#   Fold 10: val MSE = 0.5431
#   Fold 11: val MSE = 0.5044
#   Fold 12: val MSE = 0.5239
#   Fold 13: val MSE = 0.4834
#   Fold 14: val MSE = 0.3969
#   Fold 15: val MSE = 0.5152
#   Fold 16: val MSE = 0.4913
#   Fold 17: val MSE = 0.4945
#   Fold 18: val MSE = 0.5261
#   Fold 19: val MSE = 0.4422
#   Fold 20: val MSE = 0.5381
#
# Avg Val MSE for alpha=1.0, l1_ratio=0.5: 0.5089
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃▆▅▂▄▅▄▅▄▁▅▄▄▅▂▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>0.50894</td></tr><tr><td>val_mse</td><td>0.53811</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">happy-microwave-95</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/86wqslqy' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/86wqslqy</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033014-86wqslqy\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033017-jgm0ramc</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/jgm0ramc' target="_blank">chocolate-serenity-96</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/jgm0ramc' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/jgm0ramc</a>
# === Hyperparams: alpha=1.0, l1_ratio=0.8 ===
#   Fold 1: val MSE = 0.8190
#   Fold 2: val MSE = 0.9236
#   Fold 3: val MSE = 1.0115
#   Fold 4: val MSE = 0.8589
#   Fold 5: val MSE = 0.7670
#   Fold 6: val MSE = 0.8855
#   Fold 7: val MSE = 0.8497
#   Fold 8: val MSE = 0.7162
#   Fold 9: val MSE = 0.8327
#   Fold 10: val MSE = 0.8629
#   Fold 11: val MSE = 0.8159
#   Fold 12: val MSE = 0.8460
#   Fold 13: val MSE = 0.7925
#   Fold 14: val MSE = 0.6524
#   Fold 15: val MSE = 0.8334
#   Fold 16: val MSE = 0.8212
#   Fold 17: val MSE = 0.7936
#   Fold 18: val MSE = 0.8489
#   Fold 19: val MSE = 0.7273
#   Fold 20: val MSE = 0.8902
#
# Avg Val MSE for alpha=1.0, l1_ratio=0.8: 0.8274
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃▆▅▂▅▅▄▅▄▁▅▄▄▅▂▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>0.82742</td></tr><tr><td>val_mse</td><td>0.89023</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">chocolate-serenity-96</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/jgm0ramc' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/jgm0ramc</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033017-jgm0ramc\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033021-x3trtnc0</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/x3trtnc0' target="_blank">fearless-yogurt-97</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/x3trtnc0' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/x3trtnc0</a>
# === Hyperparams: alpha=10.0, l1_ratio=0.2 ===
#   Fold 1: val MSE = 0.9868
#   Fold 2: val MSE = 1.1088
#   Fold 3: val MSE = 1.2018
#   Fold 4: val MSE = 1.0360
#   Fold 5: val MSE = 0.9303
#   Fold 6: val MSE = 1.0688
#   Fold 7: val MSE = 1.0251
#   Fold 8: val MSE = 0.8853
#   Fold 9: val MSE = 1.0094
#   Fold 10: val MSE = 1.0400
#   Fold 11: val MSE = 0.9877
#   Fold 12: val MSE = 1.0173
#   Fold 13: val MSE = 0.9604
#   Fold 14: val MSE = 0.8050
#   Fold 15: val MSE = 1.0054
#   Fold 16: val MSE = 0.9952
#   Fold 17: val MSE = 0.9608
#   Fold 18: val MSE = 1.0205
#   Fold 19: val MSE = 0.8874
#   Fold 20: val MSE = 1.0746
#
# Avg Val MSE for alpha=10.0, l1_ratio=0.2: 1.0003
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃▆▅▂▅▅▄▅▄▁▅▄▄▅▂▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>1.00033</td></tr><tr><td>val_mse</td><td>1.07462</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fearless-yogurt-97</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/x3trtnc0' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/x3trtnc0</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033021-x3trtnc0\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033024-qwjjhf03</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/qwjjhf03' target="_blank">comfy-puddle-98</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/qwjjhf03' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/qwjjhf03</a>
# === Hyperparams: alpha=10.0, l1_ratio=0.5 ===
#   Fold 1: val MSE = 0.9868
#   Fold 2: val MSE = 1.1088
#   Fold 3: val MSE = 1.2018
#   Fold 4: val MSE = 1.0360
#   Fold 5: val MSE = 0.9303
#   Fold 6: val MSE = 1.0688
#   Fold 7: val MSE = 1.0251
#   Fold 8: val MSE = 0.8853
#   Fold 9: val MSE = 1.0094
#   Fold 10: val MSE = 1.0400
#   Fold 11: val MSE = 0.9877
#   Fold 12: val MSE = 1.0173
#   Fold 13: val MSE = 0.9604
#   Fold 14: val MSE = 0.8050
#   Fold 15: val MSE = 1.0054
#   Fold 16: val MSE = 0.9952
#   Fold 17: val MSE = 0.9608
#   Fold 18: val MSE = 1.0205
#   Fold 19: val MSE = 0.8874
#   Fold 20: val MSE = 1.0746
#
# Avg Val MSE for alpha=10.0, l1_ratio=0.5: 1.0003
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃▆▅▂▅▅▄▅▄▁▅▄▄▅▂▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>1.00033</td></tr><tr><td>val_mse</td><td>1.07462</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">comfy-puddle-98</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/qwjjhf03' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/qwjjhf03</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033024-qwjjhf03\logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033027-i4rz82av</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/i4rz82av' target="_blank">morning-tree-99</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/i4rz82av' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/i4rz82av</a>
# === Hyperparams: alpha=10.0, l1_ratio=0.8 ===
#   Fold 1: val MSE = 0.9868
#   Fold 2: val MSE = 1.1088
#   Fold 3: val MSE = 1.2018
#   Fold 4: val MSE = 1.0360
#   Fold 5: val MSE = 0.9303
#   Fold 6: val MSE = 1.0688
#   Fold 7: val MSE = 1.0251
#   Fold 8: val MSE = 0.8853
#   Fold 9: val MSE = 1.0094
#   Fold 10: val MSE = 1.0400
#   Fold 11: val MSE = 0.9877
#   Fold 12: val MSE = 1.0173
#   Fold 13: val MSE = 0.9604
#   Fold 14: val MSE = 0.8050
#   Fold 15: val MSE = 1.0054
#   Fold 16: val MSE = 0.9952
#   Fold 17: val MSE = 0.9608
#   Fold 18: val MSE = 1.0205
#   Fold 19: val MSE = 0.8874
#   Fold 20: val MSE = 1.0746
#
# Avg Val MSE for alpha=10.0, l1_ratio=0.8: 1.0003
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>overall_val_mse</td><td>▁</td></tr><tr><td>val_mse</td><td>▄▆█▅▃▆▅▂▅▅▄▅▄▁▅▄▄▅▂▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold</td><td>20</td></tr><tr><td>overall_val_mse</td><td>1.00033</td></tr><tr><td>val_mse</td><td>1.07462</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">morning-tree-99</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/i4rz82av' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/i4rz82av</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033027-i4rz82av\logs</code>
# Best hyperparams found: {'alpha': 0.1, 'l1_ratio': 0.2, 'k_folds': 20}
# Best val MSE: 0.13525134601374586
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>c:\Users\Administrator\Desktop\wandb\run-20250321_033030-wrhj49vh</code>
# Syncing run <strong><a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/wrhj49vh' target="_blank">final_evaluation</a></strong> to <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a>
#  View run at <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/wrhj49vh' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/wrhj49vh</a>
# Final Test MSE: 0.1382
# Final R² Score: 0.8645
# Final MAE: 0.2642
# Final MAPE: 4.5580
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Final Test MSE</td><td>▁</td></tr><tr><td>Final Test R2</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Final Test MSE</td><td>0.1382</td></tr><tr><td>Final Test R2</td><td>0.86446</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">final_evaluation</strong> at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/wrhj49vh' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep/runs/wrhj49vh</a><br> View project at: <a href='https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep' target="_blank">https://wandb.ai/yhanluo22-imperial-college-london/elasticnet-kfold-hyperparameter-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250321_033030-wrhj49vh\logs</code>
# Done.

# %%
from collections import defaultdict

# 保存测试集指标
metrics = pd.DataFrame({
    "Metric": ['MSE', 'R2', 'MAE', 'MAPE'],
    "Test_results": [mse_val, r2_val, mae_val, mape_val]
})

# 使用训练集进行 K-Fold 验证评估
validation_scores = defaultdict(list)

for i, (train_idx, val_idx) in enumerate(outer_kf.split(X_train_final)):
    X_tr, X_val = X_train_final[train_idx], X_train_final[val_idx]
    y_tr, y_val = y_train_final[train_idx], y_train_final[val_idx]

    model = ElasticNet(alpha=final_alpha, l1_ratio=final_l1_ratio, random_state=42)
    model.fit(X_tr, y_tr)
    val_preds = model.predict(X_val)

    validation_scores["Fold"].append(f"Fold_{i+1}")
    validation_scores["MSE"].append(mean_squared_error(y_val, val_preds))
    validation_scores["R2"].append(r2_score(y_val, val_preds))
    validation_scores["MAE"].append(mean_absolute_error(y_val, val_preds))
    validation_scores["MAPE"].append(mean_absolute_percentage_error(y_val, val_preds))

# 转换为 DataFrame（行是指标，列是 Fold1, Fold2...）
val_df = pd.DataFrame(validation_scores).set_index("Fold").T
val_df.reset_index(inplace=True)
val_df.rename(columns={"index": "Metric"}, inplace=True)

# 添加测试集指标列
val_df["Test"] = metrics["Test_results"]

# 保存
val_df.to_csv("LR_combined_metrics.csv", index=False)
val_df
# Out:
# Fold Metric    Fold_1     Fold_2    Fold_3    Fold_4    Fold_5    Fold_6  \
# 0       MSE  0.125496   0.143400  0.164777  0.134675  0.115904  0.168463
# 1        R2  0.870713   0.870359  0.861414  0.869869  0.875369  0.842374
# 2       MAE  0.253637   0.278613  0.279282  0.272846  0.239223  0.297750
# 3      MAPE  6.212265  10.368344  5.558281  0.923676  6.434291  2.942138
#
# Fold    Fold_7    Fold_8    Fold_9  ...   Fold_12   Fold_13    Fold_14  \
# 0     0.119812  0.146339  0.141940  ...  0.124718  0.109754   0.142191
# 1     0.882940  0.834675  0.859369  ...  0.877386  0.884752   0.823040
# 2     0.249971  0.265945  0.266197  ...  0.253116  0.236338   0.266756
# 3     7.857775  2.698146  2.904835  ...  0.587296  0.811074  15.422972
#
# Fold    Fold_15   Fold_16    Fold_17   Fold_18   Fold_19    Fold_20      Test
# 0      0.158575  0.089595   0.143534  0.121149  0.113510   0.138412  0.138200
# 1      0.841510  0.909845   0.850578  0.880761  0.872078   0.868874  0.864457
# 2      0.279043  0.232383   0.275230  0.257446  0.247603   0.260002  0.264233
# 3     16.289691  2.034237  11.535661  6.121941  7.056627  16.460373  4.557978
#
# [4 rows x 22 columns]
